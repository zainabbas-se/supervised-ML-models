# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# Logestic Regression Custom Class

# %%
class LogisticRegression:
    def __init__(self, learning_rate, no_of_iterations):  # Initialize hyperparameters
        self.learning_rate = learning_rate
        self.no_of_iterations = no_of_iterations

    def fit(self, X, Y):
        self.m, self.n = X.shape
        self.w = np.zeros(self.n)
        self.b = 0
        self.X = X
        self.Y = Y
        for i in range(self.no_of_iterations):
            self.update_weights()

    def update_weights(self):
        # Apply the sigmoid function
        Y_hat = 1 / (1 + np.exp(-(self.X.dot(self.w) + self.b)))

        # Compute gradients using the Binary Cross-Entropy loss function
        dw = (1 / self.m) * np.dot(self.X.T, (Y_hat - self.Y))
        db = (1 / self.m) * np.sum(Y_hat - self.Y)

        # Update weights and bias using Gradient Descent
        self.w = self.w - self.learning_rate * dw
        self.b = self.b - self.learning_rate * db

    def predict(self, X):
        # Predict probabilities using the sigmoid function
        Y_pred = 1 / (1 + np.exp(-(X.dot(self.w) + self.b)))
        Y_pred = np.where(Y_pred > 0.5, 1, 0)  # Convert probabilities to binary output
        return np.array(Y_pred)

# %%
df = pd.read_csv('/content/diabetes.csv')
df
# Out:
#      Index  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      0.0            6      148             72             35        0  33.6
# 1      1.0            1       85             66             29        0  26.6
# 2      2.0            8      183             64              0        0  23.3
# 3      3.0            1       89             66             23       94  28.1
# 4      4.0            0      137             40             35      168  43.1
# ..     ...          ...      ...            ...            ...      ...   ...
# 763    NaN           10      101             76             48      180  32.9
# 764    NaN            2      122             70             27        0  36.8
# 765    NaN            5      121             72             23      112  26.2
# 766    NaN            1      126             60              0        0  30.1
# 767    NaN            1       93             70             31        0  30.4
#
# ...

# %%
df.isnull().sum()
# Out:
# Index                       758
# Pregnancies                   0
# Glucose                       0
# BloodPressure                 0
# SkinThickness                 0
# Insulin                       0
# BMI                           0
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# Outcome.1                   741
# dtype: int64

# %%
df=df.drop(columns=['Index','Outcome.1'],axis=1)

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
features = df.drop(columns='Outcome',axis=1) # Select all rows and all columns except the last (features)
target = df['Outcome']                       # Select all rows from the last column (target variable)

# %%
print(features)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
print(target)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
scaler = StandardScaler()

# %%
scaler.fit(features)
# Out:
# StandardScaler()

# %%
standarad_data = scaler.transform(features)

# %%
print(standarad_data)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
X_Train,X_Test,Y_Train,Y_Test = train_test_split(standarad_data,target,test_size=0.2,random_state=2)

# %%
print("Values of the X =",X_Train.shape,X_Test.shape)
# Out:
# Values of the X = (614, 8) (154, 8)

# %%
print("Values of the Y =",Y_Train.shape,Y_Test.shape)
# Out:
# Values of the Y = (614,) (154,)

# %%
classifier = LogisticRegression(learning_rate=0.01,no_of_iterations=1000)

# %%
classifier.fit(X_Train,Y_Train)

# %%
X_Train_prediction = classifier.predict(X_Train)
training_data_accuracy = accuracy_score(Y_Train,X_Train_prediction)
print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# Accuracy score of the training data :  0.7768729641693811

# %%
X_Test_prediction = classifier.predict(X_Test)
test_data_accuracy = accuracy_score(Y_Test, X_Test_prediction)
print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# Accuracy score of the test data :  0.7662337662337663
